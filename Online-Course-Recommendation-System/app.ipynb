# %%
import sys
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from flask import Flask, render_template, request

PROJECT_PATH = os.path.dirname(os.path.abspath('C:\\Users\\user\\Documents\\codes'))  # Set the directory containing the CSV file
DATA_PATH = os.path.join(os.path.expanduser("~"), "Documents", "codes", "Online-Course-Recommendation-System", "udemy_courses.csv")
  # Adjust the path to your data file

sys.path.append(PROJECT_PATH)
#Course Recommendation Generator
class CourseGenerator:
    def __init__(self, data_path):
        self.data = pd.read_csv(data_path)
        self.tf_idf_matrix = self.calculate_tfidf_matrix()

    def calculate_tfidf_matrix(self):
        tfidf_vectorizer = TfidfVectorizer()
        tfidf_matrix = tfidf_vectorizer.fit_transform(self.data['subject'])  # Use 'subject' column
        return tfidf_matrix

    def generate_recommendations(self, course_title, num_recommendations):
        # Initialize course_index to -1
        course_index = -1

        # Find the index of the course with the given title
        matching_courses = self.data[self.data['course_title'] == course_title]
        if not matching_courses.empty:
            course_index = matching_courses.index[0]

        if course_index >= 0:
            # Calculate the cosine similarity between the selected course and all other courses
            cosine_similarities = linear_kernel(self.tf_idf_matrix[course_index], self.tf_idf_matrix).flatten()

            # Get the indices of courses with the highest similarity scores
            related_course_indices = cosine_similarities.argsort()[:-num_recommendations-1:-1]

            # Exclude the selected course itself from recommendations
            related_course_indices = [i for i in related_course_indices if i != course_index]

            # Get the recommended course titles
            recommended_courses = self.data.iloc[related_course_indices]['course_title'].tolist()

            return recommended_courses
        else:
            return []
        

app = Flask(__name__)

@app.route("/")
def home():
    return render_template("index.html")

@app.route("/result", methods=["POST"])
def result():
    if request.method == "POST":
        # Get user input from the form
        course_title = request.form.get("course_title")
        num_recommendations = int(request.form.get("num_recommendations"))

        # Create an instance of CourseGenerator with the data path
        generator = CourseGenerator(DATA_PATH)

        # Generate course recommendations
        recommendations = generator.generate_recommendations(course_title, num_recommendations)

        # Render the result page with recommendations
        return render_template("result.html", course_title=course_title, recommendations=recommendations)
    else:
        return "Sorry, there was an error."

if __name__ == "__main__":
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Sep/2023 09:57:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 09:57:26] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:57:26] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:57:28] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:57:43] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 09:57:43] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:57:43] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:57:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 09:57:48] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:57:48] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:57:52] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:58:14] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 09:58:14] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:58:14] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:59:00] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 09:59:00] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 09:59:00] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:02:32] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:02:32] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:02:32] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:03:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:03:00] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:03:00] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:03:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:03:30] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:03:30] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:05:28] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:05:28] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:05:28] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:05:57] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:05:57] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:05:57] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:06:32] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:06:32] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:06:32] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:10:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:10:37] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:10:37] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:11:18] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:11:18] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:11:18] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:11:44] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:11:44] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:11:44] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:11:52] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:11:52] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:11:53] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:02] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:12:02] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:02] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:11] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:12:11] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:11] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:34] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:12:34] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:34] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:45] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:12:45] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:45] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:50] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:12:50] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:12:50] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:13:35] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:13:35] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:13:35] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:14:18] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:14:18] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:14:18] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:14:31] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:14:31] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:14:31] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:14:59] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:14:59] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:14:59] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:15:15] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:15:15] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:15:15] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:15:24] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:15:25] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:15:25] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:17:50] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:17:50] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:17:50] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:23:01] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:23:01] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:23:01] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:23:20] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:23:20] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:23:20] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:23:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:23:35] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:23:35] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:24:04] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:24:04] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:24:04] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:24:39] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:24:39] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:24:39] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:25:36] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:25:36] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:25:36] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:25:58] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:25:58] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:25:58] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:26:03] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:27:25] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:27:26] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:27:26] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:27:50] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:27:50] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:27:50] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:28:11] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:28:11] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:28:11] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:29:13] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:29:13] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:29:13] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:29:49] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:29:49] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:29:49] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:30:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2023 10:30:00] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:30:00] "GET /assets/dist/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Sep/2023 10:30:22] "GET /assets/dist/css/bootstrap.min.css HTTP/1.1" 404 -
